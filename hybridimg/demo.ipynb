# %%
from hybrid_img import HybridImage

# %%
hybrid = HybridImage("img/sample_1/monkey.jpg", "img/sample_1/dog.jpg", 33)

# %%
hybrid.show_originals()

# %%
hybrid.show_hybrid()

# %%
hybrid.show_filtered()
